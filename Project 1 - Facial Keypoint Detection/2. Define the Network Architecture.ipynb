# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np
import cv2

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %%
## TODO: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

## TODO: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
from models import Net

net = Net(input_size=(1, 224, 224))
print(net)
print(net.out_shape_pool4)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(2, 2), stride=(2, 2))
#   (pool1): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#   (pool4): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assume that we are on a CUDA machine, then this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# # order matters! i.e. rescaling should come before a smaller crop
# data_transform = data_transform = transforms.Compose([Rescale(230),
#                                                       RandomCrop(224),
#                                                       Normalize(),
#                                                       ToTensor()])
data_transform = data_transform = transforms.Compose([Rescale((224, 224)),
                                                      Normalize(),
                                                      ToTensor()])

# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='data/training_frames_keypoints.csv',
                                             root_dir='data/training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3462
# C:\Users\rkoch\ProjectsChina\FacialKeypointDetection\Robert\data_load.py:39: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   key_pts = self.key_pts_frame.iloc[idx, 1:].as_matrix()
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
batch_size = 32

train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='data/test_frames_keypoints.csv',
                                             root_dir='data/test/',
                                             transform=data_transform)

# %%
# load test data in batches
batch_size = 16

test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints']

        # convert images to FloatTensors
        images = images.type(torch.FloatTensor)

        # forward pass to get net output
        output_pts = net(images)
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([16, 1, 224, 224])
# torch.Size([16, 68, 2])
# torch.Size([16, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='m')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(40, 20))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data   # get the image from it's wrapper
        image = image.numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.numpy()
        # undo normalization of keypoints  
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*50.0+100
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()
    
# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim

criterion = nn.MSELoss()

optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
def train_net(n_epochs, general_epoch=0):

    # prepare the net for training
    net.train()

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        
        running_loss = 0.0
        epoch_loss = 0.0
        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            # key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor).to(device)
            images = images.type(torch.FloatTensor).to(device)

            # forward pass to get outputs
            output_pts = net(images)

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts)

            # zero the parameter (weight) gradients
            optimizer.zero_grad()
            
            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            # to convert loss into a scalar and add it to the running_loss, use .item()
            running_loss += loss.item()/10
            epoch_loss += loss.item()
            if batch_i % 10 == 9:    # print every 10 batches
                print('Epoch: {}, Batch: {}, Avg. Loss: {}'.format(epoch + 1 + general_epoch, batch_i+1, running_loss))
                running_loss = 0.0
        epoch_loss = epoch_loss/(batch_i+1)
        print('Epoch: {}, Avg. Loss: {}'.format(epoch + 1 + general_epoch, epoch_loss))

    print('Finished Training')

# %%
# train your network
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)

n_epochs = 50 # start small, and increase when you've decided on your model structure and hyperparams
for i in range(n_epochs):
    net.train()
    train_net(1, general_epoch=i)
    val_loss = []
    net.eval()
    for j, sample in enumerate(test_loader):
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints'].to(device)
        # convert images to FloatTensors
        images = images.type(torch.FloatTensor).to(device)
        # forward pass to get net output
        output_pts = net(images)
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        val_loss.append(criterion(output_pts.type(torch.FloatTensor), key_pts.type(torch.FloatTensor)).item())
    print("Average validation loss after epoch", str(i+1) , ":", np.mean(val_loss))
# Out:
# Epoch: 1, Batch: 10, Avg. Loss: 0.1921909898519516
# Epoch: 1, Batch: 20, Avg. Loss: 0.11911148130893708
# Epoch: 1, Batch: 30, Avg. Loss: 0.09729821383953094
# Epoch: 1, Batch: 40, Avg. Loss: 0.09998147860169412
# Epoch: 1, Batch: 50, Avg. Loss: 0.0989900179207325
# Epoch: 1, Batch: 60, Avg. Loss: 0.09988661855459213
# Epoch: 1, Batch: 70, Avg. Loss: 0.08808072507381438
# Epoch: 1, Batch: 80, Avg. Loss: 0.0874882474541664
# Epoch: 1, Batch: 90, Avg. Loss: 0.08938482701778412
# Epoch: 1, Batch: 100, Avg. Loss: 0.07555088102817535
# Epoch: 1, Avg. Loss: 0.10262497066767938
# Finished Training
# Average validation loss after epoch 1 : 0.06011731360031634
# Epoch: 2, Batch: 10, Avg. Loss: 0.07494009695947171
# Epoch: 2, Batch: 20, Avg. Loss: 0.07135307416319847
# Epoch: 2, Batch: 30, Avg. Loss: 0.06676820665597917
# Epoch: 2, Batch: 40, Avg. Loss: 0.06943484209477901
# Epoch: 2, Batch: 50, Avg. Loss: 0.06574369259178639
# Epoch: 2, Batch: 60, Avg. Loss: 0.05875956267118454
# ...

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
net.to('cpu')
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([16, 1, 224, 224])
# torch.Size([16, 68, 2])
# torch.Size([16, 68, 2])

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:
test_images, test_outputs, gt_pts = net_sample_output()
visualize_output(test_images, test_outputs, gt_pts)
#print(test_outputs)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!

# %%
## TODO: change the name to something uniqe for each new model
model_dir = 'saved_models/'
model_name = 'keypoints_model_4_Adam.pt'

# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir+model_name)

# %%
# Save complete model instead of state dict
model_dir = 'saved_models/'
model_name = 'keypoints_model_4_Adam_complete.pt'

# after training, save your model parameters in the dir 'saved_models'
torch.save(net, model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**: I choose Adam as Optimizer. I tested SGD as well, but Adam delivered better results for the validation loss. During the Training I reduced the Learning after around 30 epochs by factor 10.
# The great about Adam is, that it is an adaptive Optimizer that is very efficient and takes into account previous gradients.
# As loss function I choose Mean-Squared-Error (MSE). The reason why I chose MSE is, that we're optimizing a regression problemin the euclidean space [-1, 1]^2. I.e. we're optimizing points in this euclidean space. The MSE is a convex loss function on euclidean spaces with only one minimum.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [raw]
# **Answer**: I started with a network architecture similar to the only proposed. The difference was, that I used GlobalMaxPooling in the last (4th) convolutional Block.
# It has this structure:
# Net(
# (conv1): Conv2d(1, 32, kernel_size=(2, 2), stride=(2, 2))
# (pool1): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
# (dropout1): Dropout(p=0.05)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout(p=0.1)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout3): Dropout(p=0.3)
#   (conv4): Conv2d(128, 512, kernel_size=(3, 3), stride=(2, 2))
#   (pool4): MaxPool2d(kernel_size=12, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (dropout4): Dropout(p=0.5)
#   (linear1): Linear(in_features=512, out_features=1024, bias=True)
#   (linear1_dropout): Dropout(p=0.5)
#   (linear2): Linear(in_features=1024, out_features=512, bias=True)
#   (linear2_dropout): Dropout(p=0.5)
#   (output): Linear(in_features=512, out_features=136, bias=True)
# )
# This model didn't perform at all and after 50 epochs only reached a validation loss of around 0.052.
# Afterwards I tried using GlobalAveragePooling instead of GlobalMaxPooling. This model didn't perform as well and reached the same level of validation error.
#
# The next model I trained was:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(2, 2), stride=(2, 2))
#   (pool1): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.05)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout(p=0.1)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout3): Dropout(p=0.3)
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#   (pool4): MaxPool2d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout4): Dropout(p=0.5)
#   (linear1): Linear(in_features=6400, out_features=1024, bias=True)
#   (linear1_dropout): Dropout(p=0.5)
#   (linear2): Linear(in_features=1024, out_features=512, bias=True)
#   (linear2_dropout): Dropout(p=0.5)
#   (output): Linear(in_features=512, out_features=136, bias=True)
# )
# This model reached a validation loss of values around 0.008.
# Thus already converged and showed a valid and good performance.
# On test images from multiple different batches the Facial Key Points were predicted accurate.
#
#
# My final architecture is the following:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(2, 2), stride=(2, 2))
#   (pool1): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.05)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout(p=0.1)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout3): Dropout(p=0.3)
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#   (pool4): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout4): Dropout(p=0.5)
#   (linear1): Linear(in_features=6400, out_features=1024, bias=True)
#   (linear1_dropout): Dropout(p=0.5)
#   (linear2): Linear(in_features=1024, out_features=512, bias=True)
#   (linear2_dropout): Dropout(p=0.5)
#   (output): Linear(in_features=512, out_features=136, bias=True)
# )
# It reaches a validation loss of 0.006641742043976425
#
# This model is stored with the following code snippet:
# # Save complete model instead of state dict
# model_dir = 'saved_models/'
# model_name = 'keypoints_model_2_Adam_complete.pt'
# # after training, save your model parameters in the dir 'saved_models'
# torch.save(net, model_dir+model_name)
# It can be loaded with:
# net = torch.load('saved_models/keypoints_model_2_Adam_complete.pt')
# net.to(device)
#
# UPDATE:
# After your suggestion I updated my model and replaced the dropout laers after the convolutional blocks by Batch normalization layers.
# The model then has the following structure:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(2, 2), stride=(2, 2))
#   (pool1): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#   (pool4): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=6400, out_features=1024, bias=True)
#   (linear1_dropout): Dropout(p=0.5)
#   (linear2): Linear(in_features=1024, out_features=512, bias=True)
#   (linear2_dropout): Dropout(p=0.5)
#   (output): Linear(in_features=512, out_features=136, bias=True)
# )
# I trained the model again with batch size 32, MSE loss and Adam as optimizer.
# The first 10 batch had an average training loss of ~0.1922 and the average loss of the first epoch was ~0.1026.
# I printed the average training loss of the last 10 batches after every 10 batches . Next to this I printed the average training loss of the complete epoch at the end and evaluated the model afterwards and printed the validation loss.
# I printed the training loss to see whether the model is getting better and learning something and if it's reaching convergency.
# I printed the validation loss to see if the models learns the correct things and is generalizing and to see if it's overfitting or not. Since the average loss of the last ten  batches had a too high variance I mainly focused on the training loss of the whole epoch to check if there was improvement or not.
# After 2 epochs both losses already decreased to:
# Epoch: 2, Avg. Loss: 0.06327561709448831
# Average validation loss after epoch 2 : 0.056377624940811374
#
# After 5 epochs both losses decreased to:
# Epoch: 5, Avg. Loss: 0.036056583320055534
# Average validation loss after epoch 5 : 0.02127821714978437
#
# After 10 epochs both losses decreased to:
# Epoch: 10, Avg. Loss: 0.022407027405746485
# Average validation loss after epoch 10 : 0.016137462147340482
#
# After 25 epochs both losses decreased to:
# Epoch: 25, Avg. Loss: 0.012512822755091234
# Average validation loss after epoch 25 : 0.009064422150579642
#
# After 50 epochs I ended the Training. The model is near convergency and there are only very few and small improvements.
# The next steps should be implementing Early Stopping and Saving of the best model during training.
# The Training and Validation loss after 50 epochs are:
# Epoch: 50, Avg. Loss: 0.0074331033077740345
# Average validation loss after epoch 50 : 0.0045729803197009835
# The complete history of the loss can be found in the next cell.

# %% [raw]
# Complete log of the losses during the training of the last model:
# Epoch: 1, Batch: 10, Avg. Loss: 0.1921909898519516
# Epoch: 1, Batch: 20, Avg. Loss: 0.11911148130893708
# Epoch: 1, Batch: 30, Avg. Loss: 0.09729821383953094
# Epoch: 1, Batch: 40, Avg. Loss: 0.09998147860169412
# Epoch: 1, Batch: 50, Avg. Loss: 0.0989900179207325
# Epoch: 1, Batch: 60, Avg. Loss: 0.09988661855459213
# Epoch: 1, Batch: 70, Avg. Loss: 0.08808072507381438
# Epoch: 1, Batch: 80, Avg. Loss: 0.0874882474541664
# Epoch: 1, Batch: 90, Avg. Loss: 0.08938482701778412
# Epoch: 1, Batch: 100, Avg. Loss: 0.07555088102817535
# Epoch: 1, Avg. Loss: 0.10262497066767938
# Finished Training
# Average validation loss after epoch 1 : 0.06011731360031634
# Epoch: 2, Batch: 10, Avg. Loss: 0.07494009695947171
# Epoch: 2, Batch: 20, Avg. Loss: 0.07135307416319847
# Epoch: 2, Batch: 30, Avg. Loss: 0.06676820665597917
# Epoch: 2, Batch: 40, Avg. Loss: 0.06943484209477901
# Epoch: 2, Batch: 50, Avg. Loss: 0.06574369259178639
# Epoch: 2, Batch: 60, Avg. Loss: 0.05875956267118454
# Epoch: 2, Batch: 70, Avg. Loss: 0.06344194076955317
# Epoch: 2, Batch: 80, Avg. Loss: 0.05970917530357838
# Epoch: 2, Batch: 90, Avg. Loss: 0.055605449900031086
# Epoch: 2, Batch: 100, Avg. Loss: 0.05519635900855065
# Epoch: 2, Avg. Loss: 0.06327561709448831
# Finished Training
# Average validation loss after epoch 2 : 0.056377624940811374
# Epoch: 3, Batch: 10, Avg. Loss: 0.05133020989596844
# Epoch: 3, Batch: 20, Avg. Loss: 0.05666311345994472
# Epoch: 3, Batch: 30, Avg. Loss: 0.051598917320370676
# Epoch: 3, Batch: 40, Avg. Loss: 0.050533327460289
# Epoch: 3, Batch: 50, Avg. Loss: 0.04637516811490059
# Epoch: 3, Batch: 60, Avg. Loss: 0.0481371883302927
# Epoch: 3, Batch: 70, Avg. Loss: 0.04581081233918667
# Epoch: 3, Batch: 80, Avg. Loss: 0.04818809144198894
# Epoch: 3, Batch: 90, Avg. Loss: 0.0458127111196518
# Epoch: 3, Batch: 100, Avg. Loss: 0.04556785337626934
# Epoch: 3, Avg. Loss: 0.048653441011358836
# Finished Training
# Average validation loss after epoch 3 : 0.03292528231989364
# Epoch: 4, Batch: 10, Avg. Loss: 0.042849207296967506
# Epoch: 4, Batch: 20, Avg. Loss: 0.04696553125977516
# Epoch: 4, Batch: 30, Avg. Loss: 0.03944897744804621
# Epoch: 4, Batch: 40, Avg. Loss: 0.04164205268025398
# Epoch: 4, Batch: 50, Avg. Loss: 0.04121334217488765
# Epoch: 4, Batch: 60, Avg. Loss: 0.0385693721473217
# Epoch: 4, Batch: 70, Avg. Loss: 0.041947802715003486
# Epoch: 4, Batch: 80, Avg. Loss: 0.03618711456656456
# Epoch: 4, Batch: 90, Avg. Loss: 0.040502451919019224
# Epoch: 4, Batch: 100, Avg. Loss: 0.038675805740058425
# Epoch: 4, Avg. Loss: 0.0405452230928141
# Finished Training
# Average validation loss after epoch 4 : 0.028018320587520698
# Epoch: 5, Batch: 10, Avg. Loss: 0.0399603871628642
# Epoch: 5, Batch: 20, Avg. Loss: 0.038482034951448446
# Epoch: 5, Batch: 30, Avg. Loss: 0.035674634575843814
# Epoch: 5, Batch: 40, Avg. Loss: 0.03796108812093735
# Epoch: 5, Batch: 50, Avg. Loss: 0.03619919065386057
# Epoch: 5, Batch: 60, Avg. Loss: 0.036154069006443024
# Epoch: 5, Batch: 70, Avg. Loss: 0.03415011931210756
# Epoch: 5, Batch: 80, Avg. Loss: 0.03372136298567057
# Epoch: 5, Batch: 90, Avg. Loss: 0.03549122735857963
# Epoch: 5, Batch: 100, Avg. Loss: 0.03384570721536874
# Epoch: 5, Avg. Loss: 0.036056583320055534
# Finished Training
# Average validation loss after epoch 5 : 0.02127821714978437
# Epoch: 6, Batch: 10, Avg. Loss: 0.036506691947579384
# Epoch: 6, Batch: 20, Avg. Loss: 0.03646716997027397
# Epoch: 6, Batch: 30, Avg. Loss: 0.037300739064812655
# Epoch: 6, Batch: 40, Avg. Loss: 0.03252154923975467
# Epoch: 6, Batch: 50, Avg. Loss: 0.031511548534035684
# Epoch: 6, Batch: 60, Avg. Loss: 0.03308943938463926
# Epoch: 6, Batch: 70, Avg. Loss: 0.030473556742072104
# Epoch: 6, Batch: 80, Avg. Loss: 0.031902052089571954
# Epoch: 6, Batch: 90, Avg. Loss: 0.02756396420300007
# Epoch: 6, Batch: 100, Avg. Loss: 0.02988801132887602
# Epoch: 6, Avg. Loss: 0.03293137558214708
# Finished Training
# Average validation loss after epoch 6 : 0.020360133116494636
# Epoch: 7, Batch: 10, Avg. Loss: 0.03054629247635603
# Epoch: 7, Batch: 20, Avg. Loss: 0.03161098286509514
# Epoch: 7, Batch: 30, Avg. Loss: 0.03233775813132525
# Epoch: 7, Batch: 40, Avg. Loss: 0.02913645338267088
# Epoch: 7, Batch: 50, Avg. Loss: 0.030094469152390956
# Epoch: 7, Batch: 60, Avg. Loss: 0.030365341342985627
# Epoch: 7, Batch: 70, Avg. Loss: 0.029766911081969737
# Epoch: 7, Batch: 80, Avg. Loss: 0.02699115537106991
# Epoch: 7, Batch: 90, Avg. Loss: 0.0334465928375721
# Epoch: 7, Batch: 100, Avg. Loss: 0.0277633111923933
# Epoch: 7, Avg. Loss: 0.0304011605474927
# Finished Training
# Average validation loss after epoch 7 : 0.028901888323681697
# Epoch: 8, Batch: 10, Avg. Loss: 0.03139305058866739
# Epoch: 8, Batch: 20, Avg. Loss: 0.028671178035438057
# Epoch: 8, Batch: 30, Avg. Loss: 0.02993214428424835
# Epoch: 8, Batch: 40, Avg. Loss: 0.026185648143291475
# Epoch: 8, Batch: 50, Avg. Loss: 0.025530519522726534
# Epoch: 8, Batch: 60, Avg. Loss: 0.028856444731354715
# Epoch: 8, Batch: 70, Avg. Loss: 0.024763128347694875
# Epoch: 8, Batch: 80, Avg. Loss: 0.026605166867375372
# Epoch: 8, Batch: 90, Avg. Loss: 0.023194416426122185
# Epoch: 8, Batch: 100, Avg. Loss: 0.027329854853451255
# Epoch: 8, Avg. Loss: 0.027066026874091646
# Finished Training
# Average validation loss after epoch 8 : 0.0213792247469632
# Epoch: 9, Batch: 10, Avg. Loss: 0.02536529917269945
# Epoch: 9, Batch: 20, Avg. Loss: 0.0243990171700716
# Epoch: 9, Batch: 30, Avg. Loss: 0.026623945496976373
# Epoch: 9, Batch: 40, Avg. Loss: 0.02481533419340849
# Epoch: 9, Batch: 50, Avg. Loss: 0.023907928727567196
# Epoch: 9, Batch: 60, Avg. Loss: 0.025459295883774758
# Epoch: 9, Batch: 70, Avg. Loss: 0.022913064435124395
# Epoch: 9, Batch: 80, Avg. Loss: 0.023562535457313065
# Epoch: 9, Batch: 90, Avg. Loss: 0.02325175330042839
# Epoch: 9, Batch: 100, Avg. Loss: 0.025642162933945653
# Epoch: 9, Avg. Loss: 0.024820749861521458
# Finished Training
# Average validation loss after epoch 9 : 0.01605757941700974
# Epoch: 10, Batch: 10, Avg. Loss: 0.022687485069036485
# Epoch: 10, Batch: 20, Avg. Loss: 0.02205880992114544
# Epoch: 10, Batch: 30, Avg. Loss: 0.021589772962033748
# Epoch: 10, Batch: 40, Avg. Loss: 0.022968414053320885
# Epoch: 10, Batch: 50, Avg. Loss: 0.024202089942991733
# Epoch: 10, Batch: 60, Avg. Loss: 0.02346232831478119
# Epoch: 10, Batch: 70, Avg. Loss: 0.02229806184768677
# Epoch: 10, Batch: 80, Avg. Loss: 0.02300705760717392
# Epoch: 10, Batch: 90, Avg. Loss: 0.02208152189850807
# Epoch: 10, Batch: 100, Avg. Loss: 0.021024739369750023
# Epoch: 10, Avg. Loss: 0.022407027405746485
# Finished Training
# Average validation loss after epoch 10 : 0.016137462147340482
# Epoch: 11, Batch: 10, Avg. Loss: 0.019202268309891222
# Epoch: 11, Batch: 20, Avg. Loss: 0.02193999756127596
# Epoch: 11, Batch: 30, Avg. Loss: 0.02098621763288975
# Epoch: 11, Batch: 40, Avg. Loss: 0.02302321037277579
# Epoch: 11, Batch: 50, Avg. Loss: 0.021178184822201726
# Epoch: 11, Batch: 60, Avg. Loss: 0.022207895293831825
# Epoch: 11, Batch: 70, Avg. Loss: 0.022590206936001774
# Epoch: 11, Batch: 80, Avg. Loss: 0.022504542395472525
# Epoch: 11, Batch: 90, Avg. Loss: 0.021570608671754598
# Epoch: 11, Batch: 100, Avg. Loss: 0.020729705598205327
# Epoch: 11, Avg. Loss: 0.021528749316589
# Finished Training
# Average validation loss after epoch 11 : 0.014092895677503275
# Epoch: 12, Batch: 10, Avg. Loss: 0.02007836364209652
# Epoch: 12, Batch: 20, Avg. Loss: 0.021300700306892396
# Epoch: 12, Batch: 30, Avg. Loss: 0.019652122911065818
# Epoch: 12, Batch: 40, Avg. Loss: 0.018711844831705095
# Epoch: 12, Batch: 50, Avg. Loss: 0.02051937850192189
# Epoch: 12, Batch: 60, Avg. Loss: 0.021955368202179668
# Epoch: 12, Batch: 70, Avg. Loss: 0.020900092832744122
# Epoch: 12, Batch: 80, Avg. Loss: 0.01958519257605076
# Epoch: 12, Batch: 90, Avg. Loss: 0.019432227406650782
# Epoch: 12, Batch: 100, Avg. Loss: 0.021734387241303922
# Epoch: 12, Avg. Loss: 0.020441935372051842
# Finished Training
# Average validation loss after epoch 12 : 0.014310825378539003
# Epoch: 13, Batch: 10, Avg. Loss: 0.018339100573211906
# Epoch: 13, Batch: 20, Avg. Loss: 0.018584253266453743
# Epoch: 13, Batch: 30, Avg. Loss: 0.022552639059722424
# Epoch: 13, Batch: 40, Avg. Loss: 0.020929804537445307
# Epoch: 13, Batch: 50, Avg. Loss: 0.018725768290460108
# Epoch: 13, Batch: 60, Avg. Loss: 0.019055167213082314
# Epoch: 13, Batch: 70, Avg. Loss: 0.0185374328866601
# Epoch: 13, Batch: 80, Avg. Loss: 0.021494850888848303
# Epoch: 13, Batch: 90, Avg. Loss: 0.020200840197503567
# Epoch: 13, Batch: 100, Avg. Loss: 0.017456501722335815
# Epoch: 13, Avg. Loss: 0.019477391137032334
# Finished Training
# Average validation loss after epoch 13 : 0.010734348709942127
# Epoch: 14, Batch: 10, Avg. Loss: 0.01849467437714338
# Epoch: 14, Batch: 20, Avg. Loss: 0.01869599744677544
# Epoch: 14, Batch: 30, Avg. Loss: 0.01851159203797579
# Epoch: 14, Batch: 40, Avg. Loss: 0.018095734063535925
# Epoch: 14, Batch: 50, Avg. Loss: 0.018412954173982143
# Epoch: 14, Batch: 60, Avg. Loss: 0.01820231173187494
# Epoch: 14, Batch: 70, Avg. Loss: 0.017534463852643966
# Epoch: 14, Batch: 80, Avg. Loss: 0.018216414004564283
# Epoch: 14, Batch: 90, Avg. Loss: 0.014844216033816339
# Epoch: 14, Batch: 100, Avg. Loss: 0.016609399765729903
# Epoch: 14, Avg. Loss: 0.017806130162346254
# Finished Training
# Average validation loss after epoch 14 : 0.011371876844870192
# Epoch: 15, Batch: 10, Avg. Loss: 0.019760432466864583
# Epoch: 15, Batch: 20, Avg. Loss: 0.019607348553836345
# Epoch: 15, Batch: 30, Avg. Loss: 0.01998910568654537
# Epoch: 15, Batch: 40, Avg. Loss: 0.01811851477250457
# Epoch: 15, Batch: 50, Avg. Loss: 0.01678401678800583
# Epoch: 15, Batch: 60, Avg. Loss: 0.015654256101697683
# Epoch: 15, Batch: 70, Avg. Loss: 0.017080044373869896
# Epoch: 15, Batch: 80, Avg. Loss: 0.017708025779575108
# Epoch: 15, Batch: 90, Avg. Loss: 0.017169545963406564
# Epoch: 15, Batch: 100, Avg. Loss: 0.01590589564293623
# Epoch: 15, Avg. Loss: 0.01780183495389759
# Finished Training
# Average validation loss after epoch 15 : 0.011262213516676304
# Epoch: 16, Batch: 10, Avg. Loss: 0.020133584458380937
# Epoch: 16, Batch: 20, Avg. Loss: 0.01732206679880619
# Epoch: 16, Batch: 30, Avg. Loss: 0.015591788850724698
# Epoch: 16, Batch: 40, Avg. Loss: 0.016910040378570558
# Epoch: 16, Batch: 50, Avg. Loss: 0.01488331966102123
# Epoch: 16, Batch: 60, Avg. Loss: 0.01682600500062108
# Epoch: 16, Batch: 70, Avg. Loss: 0.014874685555696487
# Epoch: 16, Batch: 80, Avg. Loss: 0.017677663080394264
# Epoch: 16, Batch: 90, Avg. Loss: 0.017072064615786076
# Epoch: 16, Batch: 100, Avg. Loss: 0.015371764823794362
# Epoch: 16, Avg. Loss: 0.016564585567546
# Finished Training
# Average validation loss after epoch 16 : 0.01074988471952324
# Epoch: 17, Batch: 10, Avg. Loss: 0.01827525561675429
# Epoch: 17, Batch: 20, Avg. Loss: 0.015203066542744637
# Epoch: 17, Batch: 30, Avg. Loss: 0.015335798636078835
# Epoch: 17, Batch: 40, Avg. Loss: 0.0168595764786005
# Epoch: 17, Batch: 50, Avg. Loss: 0.016292409226298328
# Epoch: 17, Batch: 60, Avg. Loss: 0.0151822941377759
# Epoch: 17, Batch: 70, Avg. Loss: 0.015515735186636449
# Epoch: 17, Batch: 80, Avg. Loss: 0.015847469586879014
# Epoch: 17, Batch: 90, Avg. Loss: 0.015544937830418347
# Epoch: 17, Batch: 100, Avg. Loss: 0.015301150642335417
# Epoch: 17, Avg. Loss: 0.015874019789791437
# Finished Training
# Average validation loss after epoch 17 : 0.011269753333181143
# Epoch: 18, Batch: 10, Avg. Loss: 0.014374437928199766
# Epoch: 18, Batch: 20, Avg. Loss: 0.014334014989435673
# Epoch: 18, Batch: 30, Avg. Loss: 0.014902967028319836
# Epoch: 18, Batch: 40, Avg. Loss: 0.01421767231076956
# Epoch: 18, Batch: 50, Avg. Loss: 0.014414151292294262
# Epoch: 18, Batch: 60, Avg. Loss: 0.01563537009060383
# Epoch: 18, Batch: 70, Avg. Loss: 0.017240378167480228
# Epoch: 18, Batch: 80, Avg. Loss: 0.014982749894261358
# Epoch: 18, Batch: 90, Avg. Loss: 0.014597653597593307
# Epoch: 18, Batch: 100, Avg. Loss: 0.015310719981789588
# Epoch: 18, Avg. Loss: 0.014935214849992082
# Finished Training
# Average validation loss after epoch 18 : 0.009101590265196805
# Epoch: 19, Batch: 10, Avg. Loss: 0.0146275719627738
# Epoch: 19, Batch: 20, Avg. Loss: 0.015291299484670163
# Epoch: 19, Batch: 30, Avg. Loss: 0.01322955610230565
# Epoch: 19, Batch: 40, Avg. Loss: 0.013269339874386785
# Epoch: 19, Batch: 50, Avg. Loss: 0.014115377329289913
# Epoch: 19, Batch: 60, Avg. Loss: 0.015185511857271194
# Epoch: 19, Batch: 70, Avg. Loss: 0.014508920256048441
# Epoch: 19, Batch: 80, Avg. Loss: 0.014469631295651198
# Epoch: 19, Batch: 90, Avg. Loss: 0.012924265768378972
# Epoch: 19, Batch: 100, Avg. Loss: 0.013945292215794325
# Epoch: 19, Avg. Loss: 0.014046921497296304
# Finished Training
# Average validation loss after epoch 19 : 0.008755720648154313
# Epoch: 20, Batch: 10, Avg. Loss: 0.013475293572992085
# Epoch: 20, Batch: 20, Avg. Loss: 0.013376880064606666
# Epoch: 20, Batch: 30, Avg. Loss: 0.014000410214066505
# Epoch: 20, Batch: 40, Avg. Loss: 0.015709580201655624
# Epoch: 20, Batch: 50, Avg. Loss: 0.013609785400331021
# Epoch: 20, Batch: 60, Avg. Loss: 0.012896754033863546
# Epoch: 20, Batch: 70, Avg. Loss: 0.014957086835056544
# Epoch: 20, Batch: 80, Avg. Loss: 0.014974814839661121
# Epoch: 20, Batch: 90, Avg. Loss: 0.015150998346507549
# Epoch: 20, Batch: 100, Avg. Loss: 0.013790164049714806
# Epoch: 20, Avg. Loss: 0.014089485032295962
# Finished Training
# Average validation loss after epoch 20 : 0.009208323890153242
# Epoch: 21, Batch: 10, Avg. Loss: 0.012980840355157853
# Epoch: 21, Batch: 20, Avg. Loss: 0.014089742023497822
# Epoch: 21, Batch: 30, Avg. Loss: 0.01466226214542985
# Epoch: 21, Batch: 40, Avg. Loss: 0.013455438055098056
# Epoch: 21, Batch: 50, Avg. Loss: 0.013028016313910484
# Epoch: 21, Batch: 60, Avg. Loss: 0.011782054789364338
# Epoch: 21, Batch: 70, Avg. Loss: 0.015456299856305122
# Epoch: 21, Batch: 80, Avg. Loss: 0.01357409413903952
# Epoch: 21, Batch: 90, Avg. Loss: 0.013279741164296865
# Epoch: 21, Batch: 100, Avg. Loss: 0.01378293186426163
# Epoch: 21, Avg. Loss: 0.013648394965182204
# Finished Training
# Average validation loss after epoch 21 : 0.009137039006288563
# Epoch: 22, Batch: 10, Avg. Loss: 0.013363445084542035
# Epoch: 22, Batch: 20, Avg. Loss: 0.014496271405369044
# Epoch: 22, Batch: 30, Avg. Loss: 0.012652998231351374
# Epoch: 22, Batch: 40, Avg. Loss: 0.013873723708093167
# Epoch: 22, Batch: 50, Avg. Loss: 0.013165998458862306
# Epoch: 22, Batch: 60, Avg. Loss: 0.013263723347336054
# Epoch: 22, Batch: 70, Avg. Loss: 0.012544124387204645
# Epoch: 22, Batch: 80, Avg. Loss: 0.013743556197732687
# Epoch: 22, Batch: 90, Avg. Loss: 0.012835398316383362
# Epoch: 22, Batch: 100, Avg. Loss: 0.012773579545319083
# Epoch: 22, Avg. Loss: 0.013303755688557932
# Finished Training
# Average validation loss after epoch 22 : 0.009523509925573456
# Epoch: 23, Batch: 10, Avg. Loss: 0.012526496686041357
# Epoch: 23, Batch: 20, Avg. Loss: 0.013302879221737384
# Epoch: 23, Batch: 30, Avg. Loss: 0.013906878512352703
# Epoch: 23, Batch: 40, Avg. Loss: 0.013423616345971823
# Epoch: 23, Batch: 50, Avg. Loss: 0.012714245636016131
# Epoch: 23, Batch: 60, Avg. Loss: 0.01269152769818902
# Epoch: 23, Batch: 70, Avg. Loss: 0.012696109246462584
# Epoch: 23, Batch: 80, Avg. Loss: 0.011845622770488262
# Epoch: 23, Batch: 90, Avg. Loss: 0.011343503929674625
# Epoch: 23, Batch: 100, Avg. Loss: 0.013699692394584417
# Epoch: 23, Avg. Loss: 0.012797775328022624
# Finished Training
# Average validation loss after epoch 23 : 0.008659016569049991
# Epoch: 24, Batch: 10, Avg. Loss: 0.01197993839159608
# Epoch: 24, Batch: 20, Avg. Loss: 0.012326764222234488
# Epoch: 24, Batch: 30, Avg. Loss: 0.013146801106631755
# Epoch: 24, Batch: 40, Avg. Loss: 0.015513191651552915
# Epoch: 24, Batch: 50, Avg. Loss: 0.014832789357751607
# Epoch: 24, Batch: 60, Avg. Loss: 0.015159014519304036
# Epoch: 24, Batch: 70, Avg. Loss: 0.015550284646451473
# Epoch: 24, Batch: 80, Avg. Loss: 0.013654421735554933
# Epoch: 24, Batch: 90, Avg. Loss: 0.013344018533825875
# Epoch: 24, Batch: 100, Avg. Loss: 0.013624918088316918
# Epoch: 24, Avg. Loss: 0.013715790234369422
# Finished Training
# Average validation loss after epoch 24 : 0.00762110176895346
# Epoch: 25, Batch: 10, Avg. Loss: 0.011735222209244965
# Epoch: 25, Batch: 20, Avg. Loss: 0.011263998132199048
# Epoch: 25, Batch: 30, Avg. Loss: 0.01360216746106744
# Epoch: 25, Batch: 40, Avg. Loss: 0.01231541335582733
# Epoch: 25, Batch: 50, Avg. Loss: 0.012126788776367903
# Epoch: 25, Batch: 60, Avg. Loss: 0.013189420662820339
# Epoch: 25, Batch: 70, Avg. Loss: 0.012590119894593953
# Epoch: 25, Batch: 80, Avg. Loss: 0.013424264825880529
# Epoch: 25, Batch: 90, Avg. Loss: 0.012693164218217135
# Epoch: 25, Batch: 100, Avg. Loss: 0.01298022912815213
# Epoch: 25, Avg. Loss: 0.012512822755091234
# Finished Training
# Average validation loss after epoch 25 : 0.009064422150579642
# Epoch: 26, Batch: 10, Avg. Loss: 0.012925811577588322
# Epoch: 26, Batch: 20, Avg. Loss: 0.012753404583781958
# Epoch: 26, Batch: 30, Avg. Loss: 0.0115302343852818
# Epoch: 26, Batch: 40, Avg. Loss: 0.011822200287133454
# Epoch: 26, Batch: 50, Avg. Loss: 0.012316606659442187
# Epoch: 26, Batch: 60, Avg. Loss: 0.012333959713578223
# Epoch: 26, Batch: 70, Avg. Loss: 0.012506174948066474
# Epoch: 26, Batch: 80, Avg. Loss: 0.01223403150215745
# Epoch: 26, Batch: 90, Avg. Loss: 0.01432415535673499
# Epoch: 26, Batch: 100, Avg. Loss: 0.012416057195514441
# Epoch: 26, Avg. Loss: 0.012482819762593562
# Finished Training
# Average validation loss after epoch 26 : 0.00879949058539101
# Epoch: 27, Batch: 10, Avg. Loss: 0.012938530929386616
# Epoch: 27, Batch: 20, Avg. Loss: 0.01438757898285985
# Epoch: 27, Batch: 30, Avg. Loss: 0.012961307074874641
# Epoch: 27, Batch: 40, Avg. Loss: 0.01088964818045497
# Epoch: 27, Batch: 50, Avg. Loss: 0.011891070939600467
# Epoch: 27, Batch: 60, Avg. Loss: 0.012362059671431776
# Epoch: 27, Batch: 70, Avg. Loss: 0.012221021670848133
# Epoch: 27, Batch: 80, Avg. Loss: 0.012194825429469347
# Epoch: 27, Batch: 90, Avg. Loss: 0.011863126931712032
# Epoch: 27, Batch: 100, Avg. Loss: 0.01201213039457798
# Epoch: 27, Avg. Loss: 0.012284455107473726
# Finished Training
# Average validation loss after epoch 27 : 0.00889720954951279
# Epoch: 28, Batch: 10, Avg. Loss: 0.011610021162778142
# Epoch: 28, Batch: 20, Avg. Loss: 0.01199854463338852
# Epoch: 28, Batch: 30, Avg. Loss: 0.011797329131513835
# Epoch: 28, Batch: 40, Avg. Loss: 0.011565494816750288
# Epoch: 28, Batch: 50, Avg. Loss: 0.011999465990811586
# Epoch: 28, Batch: 60, Avg. Loss: 0.010617092158645392
# Epoch: 28, Batch: 70, Avg. Loss: 0.010932146850973368
# Epoch: 28, Batch: 80, Avg. Loss: 0.01157210376113653
# Epoch: 28, Batch: 90, Avg. Loss: 0.012420148123055696
# Epoch: 28, Batch: 100, Avg. Loss: 0.011588058620691302
# Epoch: 28, Avg. Loss: 0.011542080371820052
# Finished Training
# Average validation loss after epoch 28 : 0.007988443180006377
# Epoch: 29, Batch: 10, Avg. Loss: 0.011962322890758515
# Epoch: 29, Batch: 20, Avg. Loss: 0.011528127361088993
# Epoch: 29, Batch: 30, Avg. Loss: 0.011656087124720216
# Epoch: 29, Batch: 40, Avg. Loss: 0.010545545350760221
# Epoch: 29, Batch: 50, Avg. Loss: 0.012770739663392306
# Epoch: 29, Batch: 60, Avg. Loss: 0.010289077926427125
# Epoch: 29, Batch: 70, Avg. Loss: 0.010677987011149524
# Epoch: 29, Batch: 80, Avg. Loss: 0.010255321348085999
# Epoch: 29, Batch: 90, Avg. Loss: 0.011120781488716603
# Epoch: 29, Batch: 100, Avg. Loss: 0.011282144207507373
# Epoch: 29, Avg. Loss: 0.011130785907046237
# Finished Training
# Average validation loss after epoch 29 : 0.0072944526351532155
# Epoch: 30, Batch: 10, Avg. Loss: 0.010097415046766402
# Epoch: 30, Batch: 20, Avg. Loss: 0.010310145094990729
# Epoch: 30, Batch: 30, Avg. Loss: 0.01130830878391862
# Epoch: 30, Batch: 40, Avg. Loss: 0.011858152505010365
# Epoch: 30, Batch: 50, Avg. Loss: 0.012233436945825814
# Epoch: 30, Batch: 60, Avg. Loss: 0.011503302864730358
# Epoch: 30, Batch: 70, Avg. Loss: 0.01089319512248039
# Epoch: 30, Batch: 80, Avg. Loss: 0.010706099402159453
# Epoch: 30, Batch: 90, Avg. Loss: 0.011871347017586232
# Epoch: 30, Batch: 100, Avg. Loss: 0.01096409186720848
# Epoch: 30, Avg. Loss: 0.011145085254427763
# Finished Training
# Average validation loss after epoch 30 : 0.006790853366825958
# Epoch: 31, Batch: 10, Avg. Loss: 0.011496961768716575
# Epoch: 31, Batch: 20, Avg. Loss: 0.012318525277078152
# Epoch: 31, Batch: 30, Avg. Loss: 0.012068352010101079
# Epoch: 31, Batch: 40, Avg. Loss: 0.010579884145408868
# Epoch: 31, Batch: 50, Avg. Loss: 0.0095442368183285
# Epoch: 31, Batch: 60, Avg. Loss: 0.011118694767355919
# Epoch: 31, Batch: 70, Avg. Loss: 0.010884863603860139
# Epoch: 31, Batch: 80, Avg. Loss: 0.011393227055668833
# Epoch: 31, Batch: 90, Avg. Loss: 0.010888735856860877
# Epoch: 31, Batch: 100, Avg. Loss: 0.011019945424050092
# Epoch: 31, Avg. Loss: 0.011235563144292852
# Finished Training
# Average validation loss after epoch 31 : 0.007605092466941902
# Epoch: 32, Batch: 10, Avg. Loss: 0.01246979320421815
# Epoch: 32, Batch: 20, Avg. Loss: 0.012553177867084741
# Epoch: 32, Batch: 30, Avg. Loss: 0.012192687392234804
# Epoch: 32, Batch: 40, Avg. Loss: 0.012826695013791323
# Epoch: 32, Batch: 50, Avg. Loss: 0.01220576148480177
# Epoch: 32, Batch: 60, Avg. Loss: 0.010761882737278938
# Epoch: 32, Batch: 70, Avg. Loss: 0.010300722438842056
# Epoch: 32, Batch: 80, Avg. Loss: 0.011399173736572265
# Epoch: 32, Batch: 90, Avg. Loss: 0.009796726889908314
# Epoch: 32, Batch: 100, Avg. Loss: 0.010637971013784409
# Epoch: 32, Avg. Loss: 0.011382875438574531
# Finished Training
# Average validation loss after epoch 32 : 0.006864022302004147
# Epoch: 33, Batch: 10, Avg. Loss: 0.011401295382529498
# Epoch: 33, Batch: 20, Avg. Loss: 0.010566905140876772
# Epoch: 33, Batch: 30, Avg. Loss: 0.009619553294032811
# Epoch: 33, Batch: 40, Avg. Loss: 0.010470787342637778
# Epoch: 33, Batch: 50, Avg. Loss: 0.01097655431367457
# Epoch: 33, Batch: 60, Avg. Loss: 0.010651219869032502
# Epoch: 33, Batch: 70, Avg. Loss: 0.00953251733444631
# Epoch: 33, Batch: 80, Avg. Loss: 0.010765383765101435
# Epoch: 33, Batch: 90, Avg. Loss: 0.00953954579308629
# Epoch: 33, Batch: 100, Avg. Loss: 0.009613275434821843
# Epoch: 33, Avg. Loss: 0.010156582673550199
# Finished Training
# Average validation loss after epoch 33 : 0.006648357553711655
# Epoch: 34, Batch: 10, Avg. Loss: 0.01051931669935584
# Epoch: 34, Batch: 20, Avg. Loss: 0.00980334668420255
# Epoch: 34, Batch: 30, Avg. Loss: 0.00965019715949893
# Epoch: 34, Batch: 40, Avg. Loss: 0.01116500934585929
# Epoch: 34, Batch: 50, Avg. Loss: 0.01051274542696774
# Epoch: 34, Batch: 60, Avg. Loss: 0.009916547499597073
# Epoch: 34, Batch: 70, Avg. Loss: 0.009884551260620355
# Epoch: 34, Batch: 80, Avg. Loss: 0.010546601703390479
# Epoch: 34, Batch: 90, Avg. Loss: 0.009900394594296811
# Epoch: 34, Batch: 100, Avg. Loss: 0.010230936110019686
# Epoch: 34, Avg. Loss: 0.010213102273848078
# Finished Training
# Average validation loss after epoch 34 : 0.0058776897292736234
# Epoch: 35, Batch: 10, Avg. Loss: 0.009698874456807971
# Epoch: 35, Batch: 20, Avg. Loss: 0.010013642348349092
# Epoch: 35, Batch: 30, Avg. Loss: 0.009277419233694672
# Epoch: 35, Batch: 40, Avg. Loss: 0.01012049652636051
# Epoch: 35, Batch: 50, Avg. Loss: 0.010625605005770922
# Epoch: 35, Batch: 60, Avg. Loss: 0.009872428188100456
# Epoch: 35, Batch: 70, Avg. Loss: 0.009555975161492824
# Epoch: 35, Batch: 80, Avg. Loss: 0.010094926785677671
# Epoch: 35, Batch: 90, Avg. Loss: 0.008767708484083413
# Epoch: 35, Batch: 100, Avg. Loss: 0.009380314499139786
# Epoch: 35, Avg. Loss: 0.009726954448899818
# Finished Training
# Average validation loss after epoch 35 : 0.00614044489338994
# Epoch: 36, Batch: 10, Avg. Loss: 0.010492288321256637
# Epoch: 36, Batch: 20, Avg. Loss: 0.009681747714057564
# Epoch: 36, Batch: 30, Avg. Loss: 0.008409697143360971
# Epoch: 36, Batch: 40, Avg. Loss: 0.009099684422835708
# Epoch: 36, Batch: 50, Avg. Loss: 0.008974242210388183
# Epoch: 36, Batch: 60, Avg. Loss: 0.008507996099069715
# Epoch: 36, Batch: 70, Avg. Loss: 0.010340716596692801
# Epoch: 36, Batch: 80, Avg. Loss: 0.008790329517796637
# Epoch: 36, Batch: 90, Avg. Loss: 0.010325961047783494
# Epoch: 36, Batch: 100, Avg. Loss: 0.00959432111121714
# Epoch: 36, Avg. Loss: 0.009463945967615198
# Finished Training
# Average validation loss after epoch 36 : 0.007144852104235669
# Epoch: 37, Batch: 10, Avg. Loss: 0.009606295684352516
# Epoch: 37, Batch: 20, Avg. Loss: 0.009467467851936816
# Epoch: 37, Batch: 30, Avg. Loss: 0.010351524548605084
# Epoch: 37, Batch: 40, Avg. Loss: 0.009416632261127234
# Epoch: 37, Batch: 50, Avg. Loss: 0.0092407017480582
# Epoch: 37, Batch: 60, Avg. Loss: 0.010064987232908607
# Epoch: 37, Batch: 70, Avg. Loss: 0.008890011394396423
# Epoch: 37, Batch: 80, Avg. Loss: 0.009300258476287127
# Epoch: 37, Batch: 90, Avg. Loss: 0.009484483394771816
# Epoch: 37, Batch: 100, Avg. Loss: 0.008778671873733402
# Epoch: 37, Avg. Loss: 0.009394685780509896
# Finished Training
# Average validation loss after epoch 37 : 0.00644619579483964
# Epoch: 38, Batch: 10, Avg. Loss: 0.009666238818317652
# Epoch: 38, Batch: 20, Avg. Loss: 0.008452380215749145
# Epoch: 38, Batch: 30, Avg. Loss: 0.008881143108010291
# Epoch: 38, Batch: 40, Avg. Loss: 0.009762227488681675
# Epoch: 38, Batch: 50, Avg. Loss: 0.009419958852231501
# Epoch: 38, Batch: 60, Avg. Loss: 0.008633979875594378
# Epoch: 38, Batch: 70, Avg. Loss: 0.008320802683010697
# Epoch: 38, Batch: 80, Avg. Loss: 0.009192428598180412
# Epoch: 38, Batch: 90, Avg. Loss: 0.008966940548270942
# Epoch: 38, Batch: 100, Avg. Loss: 0.009288473706692457
# Epoch: 38, Avg. Loss: 0.009010795841352382
# Finished Training
# Average validation loss after epoch 38 : 0.005653779131683464
# Epoch: 39, Batch: 10, Avg. Loss: 0.00897716279141605
# Epoch: 39, Batch: 20, Avg. Loss: 0.008880501100793482
# Epoch: 39, Batch: 30, Avg. Loss: 0.009375861240550875
# Epoch: 39, Batch: 40, Avg. Loss: 0.009060465963557363
# Epoch: 39, Batch: 50, Avg. Loss: 0.008594175800681116
# Epoch: 39, Batch: 60, Avg. Loss: 0.009511709166690707
# Epoch: 39, Batch: 70, Avg. Loss: 0.009349447628483177
# Epoch: 39, Batch: 80, Avg. Loss: 0.009753911197185517
# Epoch: 39, Batch: 90, Avg. Loss: 0.008910938259214164
# Epoch: 39, Batch: 100, Avg. Loss: 0.00899248402565718
# Epoch: 39, Avg. Loss: 0.009244784114694376
# Finished Training
# Average validation loss after epoch 39 : 0.005947616070090812
# Epoch: 40, Batch: 10, Avg. Loss: 0.009791744360700249
# Epoch: 40, Batch: 20, Avg. Loss: 0.00962101286277175
# Epoch: 40, Batch: 30, Avg. Loss: 0.009554329933598638
# Epoch: 40, Batch: 40, Avg. Loss: 0.007697127293795347
# Epoch: 40, Batch: 50, Avg. Loss: 0.008050336781889201
# Epoch: 40, Batch: 60, Avg. Loss: 0.008142251614481212
# Epoch: 40, Batch: 70, Avg. Loss: 0.00893637966364622
# Epoch: 40, Batch: 80, Avg. Loss: 0.008784624980762601
# Epoch: 40, Batch: 90, Avg. Loss: 0.008173838444054128
# Epoch: 40, Batch: 100, Avg. Loss: 0.009425869910046458
# Epoch: 40, Avg. Loss: 0.008965465043662885
# Finished Training
# Average validation loss after epoch 40 : 0.005761681110313048
# Epoch: 41, Batch: 10, Avg. Loss: 0.009190084878355265
# Epoch: 41, Batch: 20, Avg. Loss: 0.008960334490984679
# Epoch: 41, Batch: 30, Avg. Loss: 0.008424169896170498
# Epoch: 41, Batch: 40, Avg. Loss: 0.010001799743622542
# Epoch: 41, Batch: 50, Avg. Loss: 0.00857966933399439
# Epoch: 41, Batch: 60, Avg. Loss: 0.008363244542852045
# Epoch: 41, Batch: 70, Avg. Loss: 0.008432450983673335
# Epoch: 41, Batch: 80, Avg. Loss: 0.008171374443918467
# Epoch: 41, Batch: 90, Avg. Loss: 0.008469223650172353
# Epoch: 41, Batch: 100, Avg. Loss: 0.010086501948535442
# Epoch: 41, Avg. Loss: 0.008921314731513688
# Finished Training
# Average validation loss after epoch 41 : 0.005684694883470632
# Epoch: 42, Batch: 10, Avg. Loss: 0.009048337070271372
# Epoch: 42, Batch: 20, Avg. Loss: 0.009495832165703178
# Epoch: 42, Batch: 30, Avg. Loss: 0.00809965394437313
# Epoch: 42, Batch: 40, Avg. Loss: 0.008467997703701258
# Epoch: 42, Batch: 50, Avg. Loss: 0.008648325921967626
# Epoch: 42, Batch: 60, Avg. Loss: 0.008865448320284486
# Epoch: 42, Batch: 70, Avg. Loss: 0.008423883374780417
# Epoch: 42, Batch: 80, Avg. Loss: 0.008631440671160815
# Epoch: 42, Batch: 90, Avg. Loss: 0.009081662027165292
# Epoch: 42, Batch: 100, Avg. Loss: 0.008763062627986073
# Epoch: 42, Avg. Loss: 0.008768802615514862
# Finished Training
# Average validation loss after epoch 42 : 0.005512303753508901
# Epoch: 43, Batch: 10, Avg. Loss: 0.008211907185614108
# Epoch: 43, Batch: 20, Avg. Loss: 0.007992672780528665
# Epoch: 43, Batch: 30, Avg. Loss: 0.008462756127119064
# Epoch: 43, Batch: 40, Avg. Loss: 0.007889693509787321
# Epoch: 43, Batch: 50, Avg. Loss: 0.00878427065908909
# Epoch: 43, Batch: 60, Avg. Loss: 0.009100005496293306
# Epoch: 43, Batch: 70, Avg. Loss: 0.009295838093385099
# Epoch: 43, Batch: 80, Avg. Loss: 0.008466897998005152
# Epoch: 43, Batch: 90, Avg. Loss: 0.008744394965469837
# Epoch: 43, Batch: 100, Avg. Loss: 0.00854597850702703
# Epoch: 43, Avg. Loss: 0.008482936684281454
# Finished Training
# Average validation loss after epoch 43 : 0.005777799448340523
# Epoch: 44, Batch: 10, Avg. Loss: 0.008418384613469243
# Epoch: 44, Batch: 20, Avg. Loss: 0.007296694070100784
# Epoch: 44, Batch: 30, Avg. Loss: 0.00815075789578259
# Epoch: 44, Batch: 40, Avg. Loss: 0.008462496427819132
# Epoch: 44, Batch: 50, Avg. Loss: 0.008429215662181378
# Epoch: 44, Batch: 60, Avg. Loss: 0.007771508069708944
# Epoch: 44, Batch: 70, Avg. Loss: 0.008341638371348381
# Epoch: 44, Batch: 80, Avg. Loss: 0.007970954664051533
# Epoch: 44, Batch: 90, Avg. Loss: 0.008397111296653747
# Epoch: 44, Batch: 100, Avg. Loss: 0.007023240532726049
# Epoch: 44, Avg. Loss: 0.00805281522179689
# Finished Training
# Average validation loss after epoch 44 : 0.005880584370116799
# Epoch: 45, Batch: 10, Avg. Loss: 0.007674307934939861
# Epoch: 45, Batch: 20, Avg. Loss: 0.007641429174691439
# Epoch: 45, Batch: 30, Avg. Loss: 0.00828683190047741
# Epoch: 45, Batch: 40, Avg. Loss: 0.007876267610117794
# Epoch: 45, Batch: 50, Avg. Loss: 0.008398996107280256
# Epoch: 45, Batch: 60, Avg. Loss: 0.007320959027856589
# Epoch: 45, Batch: 70, Avg. Loss: 0.009120799507945776
# Epoch: 45, Batch: 80, Avg. Loss: 0.007940845424309373
# Epoch: 45, Batch: 90, Avg. Loss: 0.0073143414221704
# Epoch: 45, Batch: 100, Avg. Loss: 0.007566073583438992
# Epoch: 45, Avg. Loss: 0.007916911637598495
# Finished Training
# Average validation loss after epoch 45 : 0.0048987170994966005
# Epoch: 46, Batch: 10, Avg. Loss: 0.008341611595824359
# Epoch: 46, Batch: 20, Avg. Loss: 0.007409989973530174
# Epoch: 46, Batch: 30, Avg. Loss: 0.0076854225713759656
# Epoch: 46, Batch: 40, Avg. Loss: 0.007946601370349526
# Epoch: 46, Batch: 50, Avg. Loss: 0.0077951494604349145
# Epoch: 46, Batch: 60, Avg. Loss: 0.008315258752554656
# Epoch: 46, Batch: 70, Avg. Loss: 0.009052272979170084
# Epoch: 46, Batch: 80, Avg. Loss: 0.007659926544874906
# Epoch: 46, Batch: 90, Avg. Loss: 0.008160187117755414
# Epoch: 46, Batch: 100, Avg. Loss: 0.007703639985993504
# Epoch: 46, Avg. Loss: 0.007980660907069751
# Finished Training
# Average validation loss after epoch 46 : 0.005281424482486078
# Epoch: 47, Batch: 10, Avg. Loss: 0.00727273798547685
# Epoch: 47, Batch: 20, Avg. Loss: 0.008033219305798412
# Epoch: 47, Batch: 30, Avg. Loss: 0.008735587261617184
# Epoch: 47, Batch: 40, Avg. Loss: 0.00856856545433402
# Epoch: 47, Batch: 50, Avg. Loss: 0.007777092093601822
# Epoch: 47, Batch: 60, Avg. Loss: 0.008124245284125208
# Epoch: 47, Batch: 70, Avg. Loss: 0.007025075610727072
# Epoch: 47, Batch: 80, Avg. Loss: 0.007468502409756184
# Epoch: 47, Batch: 90, Avg. Loss: 0.007248188648372888
# Epoch: 47, Batch: 100, Avg. Loss: 0.007449998985975982
# Epoch: 47, Avg. Loss: 0.007778987437999303
# Finished Training
# Average validation loss after epoch 47 : 0.005420035886939387
# Epoch: 48, Batch: 10, Avg. Loss: 0.007894056197255849
# Epoch: 48, Batch: 20, Avg. Loss: 0.00785393468104303
# Epoch: 48, Batch: 30, Avg. Loss: 0.009111764794215561
# Epoch: 48, Batch: 40, Avg. Loss: 0.006782749900594354
# Epoch: 48, Batch: 50, Avg. Loss: 0.008003796264529229
# Epoch: 48, Batch: 60, Avg. Loss: 0.00728649590164423
# Epoch: 48, Batch: 70, Avg. Loss: 0.007260668510571122
# Epoch: 48, Batch: 80, Avg. Loss: 0.007142123719677329
# Epoch: 48, Batch: 90, Avg. Loss: 0.00730729210190475
# Epoch: 48, Batch: 100, Avg. Loss: 0.006993426056578755
# Epoch: 48, Avg. Loss: 0.007574047179841394
# Finished Training
# Average validation loss after epoch 48 : 0.005353719867974976
# Epoch: 49, Batch: 10, Avg. Loss: 0.007141615729779005
# Epoch: 49, Batch: 20, Avg. Loss: 0.0074030064512044195
# Epoch: 49, Batch: 30, Avg. Loss: 0.006755586527287961
# Epoch: 49, Batch: 40, Avg. Loss: 0.006563829677179456
# Epoch: 49, Batch: 50, Avg. Loss: 0.007334657106548548
# Epoch: 49, Batch: 60, Avg. Loss: 0.006532417843118309
# Epoch: 49, Batch: 70, Avg. Loss: 0.007763677323237061
# Epoch: 49, Batch: 80, Avg. Loss: 0.007324982900172471
# Epoch: 49, Batch: 90, Avg. Loss: 0.00795217389240861
# Epoch: 49, Batch: 100, Avg. Loss: 0.007774504460394382
# Epoch: 49, Avg. Loss: 0.007345463397032624
# Finished Training
# Average validation loss after epoch 49 : 0.004905077814105518
# Epoch: 50, Batch: 10, Avg. Loss: 0.0073693704325705775
# Epoch: 50, Batch: 20, Avg. Loss: 0.007381722703576087
# Epoch: 50, Batch: 30, Avg. Loss: 0.008024285966530442
# Epoch: 50, Batch: 40, Avg. Loss: 0.007336669322103262
# Epoch: 50, Batch: 50, Avg. Loss: 0.007252909475937486
# Epoch: 50, Batch: 60, Avg. Loss: 0.007534381281584501
# Epoch: 50, Batch: 70, Avg. Loss: 0.006853380287066102
# Epoch: 50, Batch: 80, Avg. Loss: 0.007686913479119538
# Epoch: 50, Batch: 90, Avg. Loss: 0.007119738310575485
# Epoch: 50, Batch: 100, Avg. Loss: 0.007180954003706575
# Epoch: 50, Avg. Loss: 0.0074331033077740345
# Finished Training
# Average validation loss after epoch 50 : 0.0045729803197009835

# %%
net = torch.load('saved_models/keypoints_model_2_Adam_complete.pt')
net.to(device)

# %%
from torchsummary import summary
print(net_)
summary(net_, (1,224, 224))

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**: I started with 5-10 epochs on GPU. This number of epochs is fast and after 3-5 epochs the loss decreased already in a steady way. For those models which didn't converge to a good performing model the loss stopped to decrease usually after 3-5 epochs. If after 5-10 epochs the loss still was decreasing I trained 20 more epochs. Then I decided to decrease the learning rate by a factor of 10 and, if the loss still decreased, I trained more epochs in an iterative way. One iteration was 25 epochs until the validation loss stopped decreasing. After each iteration I visualized a batch of the validation set with the ground truth and predicted key points to see if there is a change as well as to see where and how it improved.

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1.weight.data

w = weights1.cpu().numpy()

filter_index = 6

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
##TODO: load in and display any image from the transformed test dataset
net.eval()
net.to('cpu')
test_images, test_outputs, gt_pts = net_sample_output()

weights1 = net.conv1.weight.data

w = weights1.cpu().numpy()

filter_index = 6

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')

for i in range(batch_size):
    plt.figure(figsize=(80, 40))
    ax1 = plt.subplot(1, 2*batch_size, 2*i+1)
    ax2 = plt.subplot(1, 2*batch_size, 2*i+2)
    # un-transform the image data
    image = test_images[i].data   # get the image from it's wrapper
    image = image.numpy()   # convert to numpy array from a Tensor
    image = np.transpose(image, (1, 2, 0)).squeeze()
#     ## TODO: Using cv's filter2D function,
#     ## apply a specific set of filter weights (like the one displayed above) to the test image
    filtered = cv2.filter2D(image, -1, w[filter_index][0])
    ax1.set_title('original gray')
    ax1.imshow(image, cmap='gray')
    ax2.set_title('filtered image')
    ax2.imshow(filtered, cmap='gray')

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**: As a filter from my trained CNN I choose the filter with index 6 from the first convolutional Layer. This filter detects vertical lines. Especially it is activates by edges with dark pixels on the left side and bright pixels on the right side.
#
#
# (does it detect vertical lines or does it blur out noise, etc.) write your answer here

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
